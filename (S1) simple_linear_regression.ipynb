# %% [markdown]
# ## 📌 Simple Linear Regression
#
# 📍 **The Regression Formula:**
# # $\hat{y} = b_0 + b_1 X$
# ### **Where:**
# ✔️ **𝑦̂ (Predicted Value)** → The estimated outcome (e.g., salary 💰)
# ✔️ **X (Independent Variable)** → The input feature (e.g., years of experience 📅)
# ✔️ **b₀ (Intercept)** → The starting value when **X = 0** (base salary) 🏁
# ✔️ **b₁ (Slope Coefficient)** → The rate at which **𝑦** changes for each unit of **X** 📈
#
# ---
# **💡 Key Insight:**
# - The **intercept (b₀)** represents the salary when experience is **zero**.
# - The **slope (b₁)** shows how much the salary increases per additional year of experience.
# - If **b₁ is positive**, there’s a positive correlation (more experience → higher salary).
# - If **b₁ is negative**, there’s a negative correlation (more experience → lower salary).
#
# 🚀  Let’s go!** 🔥

# %% [markdown]
# ![linear_regression_visual.png](data:image/png;base64,...)

# %%
# 🚀 Simple Linear Regression - Comprehensive Script with Theory & Visualization
# ------------------------------------------------------------------------------
# 📌 What is Linear Regression?
# Linear Regression is a fundamental machine learning algorithm used for predicting numerical values.
# It assumes a **linear relationship** between an independent variable (X) and a dependent variable (y).
# ------------------------------------------------------------------------------
# 🔹 Formula for Simple Linear Regression:
#
#     ŷ = b₀ + b₁ * X
#
# Where:
# - ŷ  → Predicted value (dependent variable)
# - X  → Independent variable (feature)
# - b₀ → Intercept (bias term)
# - b₁ → Slope (coefficient that determines the impact of X on y)
# ------------------------------------------------------------------------------

# %% [markdown]
# ## Importing the libraries

# %%
# 📌 1. Import Required Libraries
# ------------------------------------------------------------------------------
import numpy as np  # NumPy for mathematical operations and array handling
import matplotlib.pyplot as plt  # Matplotlib for plotting graphs
import pandas as pd  # Pandas for handling tabular data (dataframes)

# %% [markdown]
# ## Importing the dataset

# %%
# 📌 2. Load the Dataset
# ------------------------------------------------------------------------------
# The dataset "Salary_Data.csv" contains two columns:
# 1️⃣ "YearsExperience" → Work experience in years (X)
# 2️⃣ "Salary" → Salary in USD ($) (y)
dataset = pd.read_csv('Salary_Data.csv')
# Splitting dataset into independent (X) and dependent (y) variables
X = dataset.iloc[:, :-1].values  # Selecting all rows, but excluding the last column
y = dataset.iloc[:, -1].values  # Selecting the last column (Salary)

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
# 📌 3. Splitting the Data into Training & Test Sets
# ------------------------------------------------------------------------------
from sklearn.model_selection import train_test_split

# ✅ 80% of data will be used for training
# ✅ 20% of data will be used for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Training the Simple Linear Regression model on the Training set

# %%
# 📌 4. Train the Linear Regression Model
# ------------------------------------------------------------------------------
from sklearn.linear_model import LinearRegression

# Initializing the Linear Regression model
regressor = LinearRegression()

# Training (fitting) the model on the training dataset
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
# 📌 5. Predict the Test Set Results
# ------------------------------------------------------------------------------
# Predicting salaries based on the trained model
y_pred = regressor.predict(X_test)

# %% [markdown]
# ## Visualising the Training set results

# %%
# ------------------------------------------
# 🎨 Regression Visualization
# ------------------------------------------
import numpy as np
import matplotlib.pyplot as plt

# 📏 Set figure size for a cinematic look
plt.figure(figsize=(12, 7))

# 🔴 Scatter plot for actual data points
plt.scatter(X_train, y_train, color='red', label='Actual Data', edgecolors='black', s=75, alpha=0.8)

# 🔵 Adjusting regression line to be properly aligned
X_range = np.linspace(min(X_train), max(X_train), 100).reshape(-1, 1)  # Generate a smooth range
plt.plot(X_range, regressor.predict(X_range),
         color='blue', linewidth=3, linestyle='--',
         label='Regression Line')

# 🎨 Customizing the visualization for a professional feel
plt.title(' Salary vs Experience (Training Set)', fontsize=16, fontweight='bold', color='#333')
plt.xlabel(' Years of Experience', fontsize=14, fontweight='bold', color='#555')
plt.ylabel(' Salary ($)', fontsize=14, fontweight='bold', color='#555')

#  Enhanced Grid and Legend
plt.grid(True, linestyle='-.', linewidth=0.75, alpha=0.7)
plt.legend(facecolor='white', edgecolor='black', fontsize=12, loc='upper left', framealpha=1)

#  Aesthetic touch with a dark background
plt.style.use('fivethirtyeight')

#  Show the perfected visualization
plt.show()

# %% [markdown]
# ## Visualising the Test set results

# %%
# ------------------------------------------
# 🎯 Enhanced Test Set Visualization
# ------------------------------------------
import numpy as np
import matplotlib.pyplot as plt

# 📏 Set figure size for a polished look
plt.figure(figsize=(12, 7))

# 🔴 Scatter plot for actual test data points
plt.scatter(X_test, y_test, color='red', label='Actual Data', edgecolors='black', s=75, alpha=0.8)

# 🔵 Regression Line (Ensuring Proper Alignment)
X_range = np.linspace(min(X_test), max(X_test), 100).reshape(-1, 1)  # Generate a smooth range
plt.plot(X_range, regressor.predict(X_range),
         color='blue', linewidth=3, linestyle='--',
         label='Regression Line')

# 🎨 Customizing the visualization
plt.title(' Salary vs Experience (Test Set)', fontsize=16, fontweight='bold', color='#333')
plt.xlabel(' Years of Experience', fontsize=14, fontweight='bold', color='#555')
plt.ylabel(' Salary ($)', fontsize=14, fontweight='bold', color='#555')

# 🏆 Grid and Legend for better readability
plt.grid(True, linestyle='-.', linewidth=0.75, alpha=0.7)
plt.legend(facecolor='white', edgecolor='black', fontsize=12, loc='upper left', framealpha=1)

# 🌟 Aesthetic touch with a modern theme
plt.style.use('fivethirtyeight')

# 🚀 Show the enhanced test set visualization
plt.show()

# %% [markdown]
# # Understanding Model Coefficients

# %%
# 📌 7. Understanding Model Coefficients
# ------------------------------------------------------------------------------
# 🔹 Once the linear regression model is trained, it calculates two key values:
#
#    1️⃣ Intercept (b₀) → The starting point of the regression line on the y-axis.
#    2️⃣ Slope (b₁) → The rate of change of y with respect to x (how much y changes when x increases by 1 unit).
#
# These values help us define the equation of the regression line:
#
#    ŷ = b₀ + b₁ * X
#
# Let's extract and display these coefficients:

b0 = regressor.intercept_  # Intercept (b₀) → Base salary when experience is 0
b1 = regressor.coef_[0]    # Slope (b₁) → How much salary increases per year of experience

# Printing the calculated coefficients with clear formatting
print(f"📌 🔥 Intercept (b₀): {b0:.2f}")  # Displays base salary when experience = 0
print(f"📌 🔥 Coefficient (b₁): {b1:.2f}")  # Displays increase in salary per extra year

# 🔍 **Example Interpretation**
# Let's say:
# - b₀ (Intercept) = $26,7*80.10
# - b₁ (Slope) = $9,312.58
# This means:
# - A person with **0 years of experience** is expected to earn **$26,780.10** (b₀).
# - For **each additional year** of experience, salary increases by **$9,312.58** (b₁).

# ------------------------------------------------------------------------------
# Out:
# 📌 🔥 Intercept (b₀): 26780.10
# 📌 🔥 Coefficient (b₁): 9312.58

# %% [markdown]
# # Validating the Regression Equation

# %%
# ------------------------------------------
# 🔥 8. Validating the Regression Equation
# ------------------------------------------
# Now, let's validate our regression model using the core equation of Linear Regression:
#
#   ŷ = b₀ + b₁ * X
#
# - ŷ: Predicted salary
# - b₀: Intercept (base salary when experience = 0)
# - b₁: Slope (increase in salary per year of experience)
# - X: Years of experience
#
# The goal is to verify if our model correctly follows this equation.

# ------------------------------------------
# 🎯 Step 1: Predict Salary for 12 Years of Experience
# ------------------------------------------
# - We choose **12 years of experience** as an example.
# - Convert it into a **2D array** for model input.
# - Pass it through our trained regression model.

years_of_experience = np.array([[12]])  # Convert to 2D array
predicted_salary = regressor.predict(years_of_experience)  # Predict salary

# ------------------------------------------
# 📌 Step 2: Display the Predicted Salary
# ------------------------------------------
# - Print the predicted salary in a well-formatted way.
# - Adds **thousands separator and two decimal places** for clarity.

print(f"🔥🚀 **Predicted Salary for 12 years of experience**: **${predicted_salary[0]:,.2f}**")

# ------------------------------------------
# 📊 Step 3: Manually Verifying the Regression Formula
# ------------------------------------------
# To ensure correctness, we manually calculate the salary:
#
# Given:
#   - Intercept (b₀) = 26,780.10
#   - Slope (b₁) = 9,312.58
#   - Experience (X) = 12
#
# Manual Calculation:
#   ŷ = 26,780.10 + (9,312.58 × 12)
#   ŷ = 26,780.10 + 111,750.96
#   ŷ ≈ **$138,531.00**
#
# ✅ The manually calculated value **matches the model’s prediction**, confirming that our regression model is correctly following the equation.

# ------------------------------------------
# ✅ Final Conclusion: Model Verification Complete!
# ------------------------------------------
# - The model correctly applies the linear regression equation.
# - The **predictions are accurate**, proving the model is functioning as expected.
# - We can confidently use this model for real-world predictions!
# Out:
# 🔥🚀 **Predicted Salary for 12 years of experience**: **$138,531.00**

# %% [markdown]
# #  Making Predictions with New Data

# %%
# ------------------------------------------
# 🔮 9. Making Predictions with New Data
# ------------------------------------------
# Now that the model is trained, we can **predict salaries** for any given experience level.
# We can feed in new experience values to the model and get predicted salaries.

# ------------------------------------------
# 📌 Step 1: Define New Experience Levels
# ------------------------------------------
# - Let's predict salaries for **different levels of experience**.
# - We create a NumPy array with various experience levels.
# - The model will **predict** salaries based on these inputs.

new_experience = np.array([[5], [8], [15], [20]])  # Define multiple experience levels

# ------------------------------------------
# 🎯 Step 2: Use the Model to Predict Salaries
# ------------------------------------------
# - We pass our new experience data into the trained model.
# - The model will output the predicted salaries.

predicted_salaries = regressor.predict(new_experience)

# ------------------------------------------
# 📌 Step 3: Print Predicted Results
# ------------------------------------------
# - We iterate through the predicted salaries and print them.
# - Each **experience level** is paired with its **predicted salary**.

for exp, salary in zip(new_experience.flatten(), predicted_salaries):
    print(f"🔹 Experience: {exp} years → Predicted Salary: ${salary:,.2f}")

# ------------------------------------------
# 📊 Observations & Real-World Use Cases
# ------------------------------------------
# ✅ We can now use this model in **real-world applications**, such as:
#     ✔ HR Salary Prediction Systems
#     ✔ Career Growth Analysis
#     ✔ Financial Forecasting
#     ✔ AI-based Job Market Insights

# ------------------------------------------------------------------------------
# Out:
# 🔹 Experience: 5 years → Predicted Salary: $73,342.97
# 🔹 Experience: 8 years → Predicted Salary: $101,280.70
# 🔹 Experience: 15 years → Predicted Salary: $166,468.73
# 🔹 Experience: 20 years → Predicted Salary: $213,031.60

# %% [markdown]
# # Evaluating Model Performance

# %%
# ------------------------------------------
# 🎯 10. Evaluating Model Performance
# ------------------------------------------
# Now, we need to **evaluate how well our model performs**.
# We use key metrics like:
# - **Mean Absolute Error (MAE)**: Measures average absolute prediction error.
# - **R² Score**: Measures how well the model explains variance in the data.

from sklearn.metrics import mean_absolute_error, r2_score  # Importing evaluation metrics

# ------------------------------------------
# 🏆 Step 1: Calculate Performance Metrics
# ------------------------------------------

# 🔹 Mean Absolute Error (MAE)
# -------------------------------------
# - Measures the **average absolute difference** between actual values (y_test) and predicted values (y_pred).
# - It **does NOT** consider direction (positive/negative), only absolute errors.
# - Formula: MAE = (1/n) * Σ | y_actual - y_predicted |
# - Lower MAE = **Better Model Performance**.

mae = mean_absolute_error(y_test, y_pred)

# 🔹 R² Score (Coefficient of Determination)
# -------------------------------------
# - R² measures **how well the regression model fits the data**.
# - Formula: R² = 1 - (SS_residual / SS_total)
# - **Interpreting R²:**
#     - **1.0** → Perfect fit (explains 100% variance).
#     - **≥ 0.8** → Strong fit (explains ~80% of variance).
#     - **0.5 - 0.8** → Moderate fit (explains ~50-80% variance).
#     - **< 0.5** → Weak fit (model doesn’t explain much variance).

r2 = r2_score(y_test, y_pred)

# ------------------------------------------
# 🖨 Step 2: Print the Evaluation Metrics
# ------------------------------------------
print(f"📊 Mean Absolute Error (MAE): {mae:.2f}")
print(f"📈 R² Score: {r2:.4f} (closer to 1 = better fit)")

# ------------------------------------------
# 📌 Understanding R² Score - Quick Guide
# ------------------------------------------
# - **If R² = 1**, the model **perfectly fits** the data.
# - **If R² = 0.8**, the model explains **80%** of the variance.
# - **If R² < 0.5**, the model is **not a good fit**.

# ------------------------------------------
# ✅ Summary of Model Evaluation
# ------------------------------------------
# - 🔹 We extracted the regression **coefficients (b₀, b₁)**.
# - 🔹 We **validated** the equation by checking predictions.
# - 🔹 We tested the model with **new experience levels**.
# - 🔹 We evaluated model accuracy using **MAE and R² Score**.
# - 🔹 **Our regression model is now fully operational! 🚀**
# Out:
# 📊 Mean Absolute Error (MAE): 2446.17
# 📈 R² Score: 0.9882 (closer to 1 = better fit)

# %% [markdown]
# # 📊 Map of Regression Error

# %%
# 📌 Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# 🎯 Create a figure and axis for the plot
fig, ax = plt.subplots(figsize=(10, 7))

# 📊 Generate a grid of points representing experience (X) and salary (Y)
# Experience range: 0 to 20 years, Salary range: 20,000 to 250,000
X_grid, Y_grid = np.meshgrid(np.linspace(0, 20, 100), np.linspace(20000, 250000, 100))

# ⚙️ Compute the regression error at each point
# This represents how far off the predicted salary is from actual salary
Error_grid = np.abs(b0 + b1 * X_grid - Y_grid)

# 🎨 Plot the filled contour map of the regression error
contour = ax.contourf(X_grid, Y_grid, Error_grid, cmap='coolwarm_r', levels=50)
cbar = plt.colorbar(contour, ax=ax)  # Add color legend (bar)

# 🛠 Add contour lines for more details
lines = ax.contour(X_grid, Y_grid, Error_grid, colors='black', linewidths=0.5)
ax.clabel(lines, inline=True, fontsize=8)  # Label contour lines

# 🏷 Set axis labels and title
ax.set_xlabel('Experience (Years)', fontsize=12)  # X-axis: Experience in years
ax.set_ylabel('Salary ($)', fontsize=12)  # Y-axis: Salary in dollars
ax.set_title('📊 Contour Map of Regression Error', fontsize=14, fontweight="bold")  # Main title

# 🔎 Highlight areas of low and high error
plt.text(2, 50000, "Low Error", fontsize=16, color="blue", fontweight="bold")  # Small error zone
plt.text(15, 200000, "High Error", fontsize=16, color="red", fontweight="bold")  # Large error zone

# 🚀 Show the final plot
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# <div style="border-left: 8px solid #36c; padding: 15px; background-color: #f0f4ff;">
#     <h1>✅ Summary:</h1>
#     <h2>✅ 📈 Linear Regression finds the best-fitting straight line for a dataset.</h2>
#     <h2>✅ 📊 Data was split into training and testing sets (80%/20%).</h2>
#     <h2>✅ 🤖 The model was trained and successfully predicted salaries based on experience.</h2>
#     <h2>✅ 📉 The regression equation was validated using test cases.</h2>
#     <h2>✅ 🎨 Finally, we visualized the regression formula in an <b>epic way!</b></h2>
# </div>
