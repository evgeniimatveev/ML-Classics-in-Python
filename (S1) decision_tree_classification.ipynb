# %% [markdown]
# # 🔷 Overview
#
# Decision Tree (**DT**) is a popular and interpretable algorithm used for **classification tasks** based on a tree-like model of decisions. It splits data into subsets based on feature values, making it a **powerful yet explainable** model for various real-world applications. DT classifiers are widely used in **credit scoring, medical diagnosis, fraud detection, and recommendation systems**.
#
# ## ❓ What is Decision Tree?
#
# Decision Tree classifiers use a **tree-based structure** to make predictions by recursively splitting data based on feature conditions. Each internal node represents a decision rule, each branch represents an outcome, and each leaf node represents a class label. **DT performs well** in many applications, especially with **structured and categorical data**.
#
# ## 🔥 Popular Decision Tree Variants:
#
# - **ID3 (Iterative Dichotomiser 3)** 🌱 Uses entropy and information gain for feature selection.
# - **C4.5** 🌳 An extension of ID3 that handles both categorical and continuous data.
# - **CART (Classification and Regression Trees)** 📊 Uses Gini impurity or entropy, supports both classification and regression.
# - **CHAID (Chi-Square Automatic Interaction Detector)** 🏆 Uses chi-square statistics for multi-way splits.
#
# ---
#
# 💡 **Key Strengths**: Easy to interpret, no need for feature scaling, handles both numerical and categorical data.
#
# ⚠️ **Limitations**: Prone to overfitting, sensitive to noisy data, biased towards dominant features.

# %% [markdown]
# # 🌳 The Decision Tree Formula:
#
# A Decision Tree (**DT**) model makes predictions by **recursively splitting** the dataset based on feature values until it reaches a class label.
#
# **Mathematically, it minimizes impurity:**
# $$
# I(t) = - \sum_{i=1}^{c} p_i \log_2(p_i)
# $$
# where:
# - \( I(t) \) is the impurity measure (e.g., Entropy or Gini).
# - \( p_i \) is the probability of class \( i \) at node \( t \).
#
# ### Where:
# ✔ **(I(t)) (Impurity Measure)** → Measures how mixed the classes are at a given node. Common choices:
#   - **Entropy:** Used in **ID3, C4.5**, based on information gain.
#   - **Gini Impurity:** Used in **CART**, measures the probability of incorrect classification.
#
# ✔ **(Split Criterion)** → The method used to choose the best feature for splitting:
#   - **Information Gain:** Used in ID3 and C4.5.
#   - **Gini Index:** Used in CART.
#
# ✔ **(Tree Nodes)** → A decision tree consists of:
#   - **Root Node:** The first decision point.
#   - **Internal Nodes:** Where decisions are made.
#   - **Leaf Nodes:** Represent class labels.
#
# ✔ **(Recursive Splitting)** → Process of dividing data into subsets until each subset belongs to a single class or meets a stopping condition.
#
# ---
#
# ## 🔹 Choosing the Right Decision Tree Variant:
#
# - **ID3 (Iterative Dichotomiser 3)** 🌱 Uses **Entropy & Information Gain** for selecting the best split.
# - **C4.5** 🌳 An improvement over ID3 that handles **both categorical & numerical data**.
# - **CART (Classification and Regression Trees)** 📊 Uses **Gini impurity**, supports **both classification & regression**.
# - **CHAID (Chi-Square Automatic Interaction Detector)** 🏆 Uses **chi-square statistics** for multi-way splits.
#
# ---
#
# ## 🔑 Key Insight:
#
# ✅ **Decision Trees are highly interpretable**, making them ideal for business decisions and medical diagnosis. 📊
# ✅ **Handles both numerical and categorical data**, providing flexibility in applications.
# ✅ **Performs well even with non-linear relationships**, making it effective for complex patterns.
# ⚠️ **Prone to overfitting**, especially with deep trees. Use pruning or ensemble methods to mitigate this.
# 📌 **Commonly used in credit scoring, fraud detection, and recommendation systems**.

# %% [markdown]
# # WIZ 🌳

# %% [markdown]
# ![output.png](data:image/png;base64,...)

# %% [markdown]
# # 📌 Import Libraries

# %%
import numpy as np  # 📌 Importing NumPy for numerical operations
import matplotlib.pyplot as plt  # 📌 Importing Matplotlib for visualization
import pandas as pd  # 📌 Importing Pandas for data manipulation
import seaborn as sns  # 📌 Importing Seaborn for enhanced visualization
from sklearn.model_selection import train_test_split  # 📌 Function to split dataset into training and testing sets
from sklearn.preprocessing import StandardScaler  # 📌 Standardizing features for improved model performance
from sklearn.tree import DecisionTreeClassifier, plot_tree  # 📌 Importing Decision Tree classifier and visualization tool
from sklearn.metrics import classification_report, confusion_matrix  # 📌 Functions to evaluate model performance
from matplotlib.colors import ListedColormap  # 📌 Used for coloring decision boundary plots

# %% [markdown]
# # 📌 Load dataset from CSV file

# %%
# 📌 Load dataset from CSV file
file_path = "Social_Network_Ads.csv"  # 📌 File path for dataset
df = pd.read_csv(file_path)  # 📌 Reading CSV into DataFrame

# %% [markdown]
# # 📌 Display first few rows of dataset to understand structure

# %%
# 📌 Display first few rows of dataset to understand structure
display(df.head())
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %% [markdown]
# # 📌 Extracting features (Age, EstimatedSalary) and target variable (Purchased)

# %%
# 📌 Extracting features (Age, EstimatedSalary) and target variable (Purchased)
X = df[['Age', 'EstimatedSalary']].values  # 📊 Feature matrix: Age & Estimated Salary
y = df['Purchased'].values  # 🎯 Target variable: Purchased (0 or 1)

# %% [markdown]
# # 📌 Splitting data into training (75%) and testing (25%) sets

# %%
# 📌 Splitting data into training (75%) and testing (25%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# # 📌 Standardizing the features for better model performance

# %%
# 📌 Standardizing the features for better model performance
sc = StandardScaler()
X_train = sc.fit_transform(X_train)  # 🏋️‍♂️ Fitting and transforming training data
X_test = sc.transform(X_test)  # 🔄 Transforming test data using same scaler

# %% [markdown]
# # 📌 Training a Decision Tree Classifier with a maximum depth of 4

# %%
# 📌 Training a Decision Tree Classifier with a maximum depth of 4
classifier = DecisionTreeClassifier(criterion='entropy', random_state=42, max_depth=4)
classifier.fit(X_train, y_train)  # 🚀 Training the classifier
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=42)

# %% [markdown]
# # 📌 Function to plot decision boundaries

# %%
# 📌 Function to plot decision boundaries
def plot_decision_boundary(X_set, y_set, model, title):
    X1, X2 = np.meshgrid(
        np.arange(start=X_set[:, 0].min() - 1, stop=X_set[:, 0].max() + 1, step=0.01),
        np.arange(start=X_set[:, 1].min() - 1, stop=X_set[:, 1].max() + 1, step=0.01)
    )  # 🔹 Creating a grid for visualization
    plt.figure(figsize=(10, 6))  # 🖼 Setting figure size
    plt.contourf(X1, X2, model.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
                 alpha=0.5, cmap=ListedColormap(('lightblue', 'lightcoral')))  # 🎨 Plotting decision regions

    # 📌 Scatter plot for actual data points
    for i, j in enumerate(np.unique(y_set)):
        plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                    c=ListedColormap(('blue', 'red'))(i), label=f'Class {j}')  # 📊 Plotting data points

    plt.title(title)  # 🏷 Setting title
    plt.xlabel('Age (scaled)')  # 🔢 Label for X-axis
    plt.ylabel('Estimated Salary (scaled)')  # 💰 Label for Y-axis
    plt.legend()  # 📜 Adding legend
    plt.show()  # 🖼 Display plot

# %% [markdown]
# # 📌 Plot decision boundaries for training data

# %%
# 📌 Plot decision boundaries for training data
plot_decision_boundary(X_train, y_train, classifier, "Decision Tree Decision Boundary (Training Set)")
# Out:
# <ipython-input-10-6e8068aa3814>:13: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],

# %% [markdown]
# # 📌 Plot decision boundaries for testing data

# %%
# 📌 Plot decision boundaries for testing data
plot_decision_boundary(X_test, y_test, classifier, "Decision Tree Decision Boundary (Testing Set)")
# Out:
# <ipython-input-10-6e8068aa3814>:13: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],

# %% [markdown]
# # 📌 Visualizing the decision tree structure

# %%
# 📌 Visualizing the decision tree structure
plt.figure(figsize=(12, 8))  # 🖼 Setting figure size for tree visualization
plot_tree(classifier, feature_names=['Age', 'EstimatedSalary'], class_names=['No', 'Yes'], filled=True)  # 🌳 Plotting the tree
plt.title("Decision Tree Visualization")  # 🏷 Adding title
plt.show()  # 🖼 Display tree visualization

# %% [markdown]
# # 📌 Testing different depths to analyze performance

# %%
# 📌 Testing different depths to analyze performance
depths = [2, 4, 6, 8, 10]
for depth in depths:
    dt = DecisionTreeClassifier(max_depth=depth, random_state=42)  # 🏗 Creating new Decision Tree with different depths
    dt.fit(X_train, y_train)  # 🚀 Training the model
    print(f'🌳 Max Depth {depth}: Accuracy = {dt.score(X_test, y_test):.4f}')  # 📊 Printing accuracy for each depth
# Out:
# 🌳 Max Depth 2: Accuracy = 0.9200
# 🌳 Max Depth 4: Accuracy = 0.9100
# 🌳 Max Depth 6: Accuracy = 0.8800
# 🌳 Max Depth 8: Accuracy = 0.8400
# 🌳 Max Depth 10: Accuracy = 0.8300

# %% [markdown]
# # 📌 Generating predictions on test set

# %%
# 📌 Generating predictions on test set
y_pred = classifier.predict(X_test)  # 🎯 Predicting labels for test data

# %% [markdown]
# # 📌 Confusion Matrix visualization

# %%
# 📌 Confusion Matrix visualization
conf_matrix = confusion_matrix(y_test, y_pred)  # 📊 Computing confusion matrix
plt.figure(figsize=(6, 5))  # 🖼 Setting figure size
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])  # 🎨 Creating heatmap
plt.xlabel('Predicted')  # 🔢 X-axis label
plt.ylabel('Actual')  # 🎯 Y-axis label
plt.title('Confusion Matrix')  # 🏷 Title
plt.show()  # 🖼 Display heatmap

# %% [markdown]
# # 📊 Printing classification report

# %%
# 📌 Printing classification report
print("📊 Classification Report:\n")  # 🏷 Title for report
print(classification_report(y_test, y_pred))  # 📜 Printing precision, recall, F1-score
# Out:
# 📊 Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92        63
#            1       0.89      0.84      0.86        37
#
#     accuracy                           0.90       100
#    macro avg       0.90      0.89      0.89       100
# weighted avg       0.90      0.90      0.90       100

# %% [markdown]
# # 🌟  Feature Importance Analysis

# %%
# 📌 Feature Importance Analysis
feature_importance = classifier.feature_importances_  # 🌟 Extracting feature importance
for feature, importance in zip(['Age', 'EstimatedSalary'], feature_importance):
    print(f'🔥 Feature Importance: {feature} = {importance:.3f}')  # 📊 Displaying feature importance
# Out:
# 🔥 Feature Importance: Age = 0.456
# 🔥 Feature Importance: EstimatedSalary = 0.544
